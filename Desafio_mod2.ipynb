# %%
# importando bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans
from itertools import combinations
from datetime import date
from datetime import datetime

# %%
from google.colab import files # carregando arquivo
uploaded = files.upload()

# %%
df_bike= pd.read_csv("bike-sharing.csv")

# %%
df_bike.head(6) # mostrando os dados

# %%
df_bike.loc[[0],['season', 'year']]

# %%
df_bike.describe()

# %%
instancias,atributos = df_bike.shape

# %%
print("O dataset possue {} instâncias e {} atributos".format(instancias,atributos)) ###  questão 01

# %%
df_bike['windspeed'].mean() ### questão 02

# %%
df_bike['temp'].mean() ### questão 03

# %%
df_bike['year'].value_counts() ### questão 04 e 05 //ano (0: 2011, 1:2012);
#bike[df_bike['year']==1].shape 
#bike[df_bike['year']==0].shape

# %%
df_bike.datetime=pd.to_datetime(df_bike.datetime)

# %%
df_bike.dtypes

# %%
df_bike = df_bike.set_index('datetime')

# %%
df_bike.loc[df_bike.index <= '2011-12-31', ['total_count']].sum() ## questão 06

# %%
df_bike.loc[df_bike.index > '2011-12-31', ['total_count']].sum()  ## questão 07

# %%
df_bike.groupby(by='season').mean() ## questão 08 e 09

# %%
df_bike.groupby(by='hour').mean() ## questão 10 e 11

# %%
df_bike.groupby(by='weekday').mean()## questão 12 e 13

# %%
df_bike[df_bike['weekday'] == 3].groupby(by='hour').mean()## questão 14

# %%
df_bike[df_bike['weekday'] == 6].groupby(by='hour').mean()## questão 15

# %%
df_bike.info()

# %%
df_bike.isnull().sum()  #contando valores
