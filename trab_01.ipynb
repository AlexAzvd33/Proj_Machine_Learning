# %% [markdown]
# CODIGO 01

# %%
idade = int(input("Entre com a sua idade: "))
nova_idade = idade + 1
print("No próximo ano você terá {}".format(nova_idade))

# %% [markdown]
# CODIGO 02

# %%
lado_a= 35
lado_b= 14.33333
area_do_retangulo= (lado_a)*(lado_b)
print('O retangulo do lado A = %d e lado B = %.2f é %.3f' %(lado_a,lado_b,area_do_retangulo))

# %% [markdown]
# CODIGO 03

# %%
lista_1= [1,2,"IGTI"]
lista_2= [2,3,"Bootcamp"]
lista_3 = lista_1 + lista_2
lista_3.append(5)
print(lista_3)
print(lista)

# %% [markdown]
# CODIGO 04

# %%
chute= int(input('Entre com um valor inteiro de 0 a 30: '))
adivinhacao=[5,6,10,14,16,20,30]
if chute in adivinhacao:
  print('Você acertou um dos números que eu estava pensando.')

  if chute > 15:
    print('Esse número é maior do que 20.')

  if chute < 20:
    print('Esse número é menor do que 20.')

  print('Você é fera!')
else:
  print('Que pena, você errou. Pode tentar outra vez.')
print('Obrigado por participar.')
print(type(adivinhacao))
print(type(chute))

# %% [markdown]
# CODIGO 5

# %%
frutas = ["maça", "banana", "uva", "goiaba"]
frutas.append('chibimba')
for x in frutas:
  if x == "uva":
    break
  print(x)

# %% [markdown]
# CODIGO 6

# %%
n = 5 
while n >= 0:
  n -= 1
  print(n)
